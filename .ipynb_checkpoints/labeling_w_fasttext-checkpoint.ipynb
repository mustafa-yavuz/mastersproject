# %%
import numpy as np
import pandas as pd
import pickle, os
import spacy
import fasttext

from tqdm.auto import tqdm, trange
from scipy.spatial.distance import cosine

from utils import embedding, get_embedding, text_cleaning, find_top_n , tfidf_sentences

from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ### Preprocessing

# %%
# Loading spacy nlp model
nlp = spacy.load("en_core_web_sm")

# %%
# Getting the titles from file names
title_list = []

for file in os.listdir("Local pdf text files"):
  if file.endswith(".txt"):
    title_list.append(file.split(".")[0])

# %%
# Getting the text from local text files
pdf_list = []
    
for file in os.listdir("Local pdf text files"):
  if file.endswith(".txt"):
    with open("Local pdf text files/"+file,"r",encoding="utf8") as f:
        pdf_list.append(f.read())

# %%
# cleaning text and titles
pdfs = list(map(lambda x: text_cleaning(x,nlp), pdf_list))
titles = list(map(lambda x: text_cleaning(x,nlp), title_list))

# lemmatization
pdfs = list(map(lambda x: ' '.join([token.lemma_ for token in x]), pdfs))
titles = list(map(lambda x: ' '.join([token.lemma_ for token in x]), titles))

# removing PRON after lemmatization
pdfs = list(map(lambda x: x.replace("-PRON-",""), pdfs))
titles = list(map(lambda x: x.replace("-PRON-",""), titles))

# %%
# Tfidf for abstracts
vec_abs = TfidfVectorizer(max_df=0.9,min_df=2,stop_words='english')
vec_abs.fit(pdfs)

# Tfidf for titles
vec_title = TfidfVectorizer(max_df=0.9,min_df=2,stop_words='english')
vec_title.fit(titles)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=0.9, max_features=None,
#                 min_df=2, ngram_range=(1, 1), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words='english', strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)

# %% [markdown]
# ### Model Installation

# %%
path = "crawl-300d-2M-subword.vec"

with open('training_data.txt','w',encoding="utf-8") as f:
    f.write('\n'.join(pdfs))

train_data = 'training_data.txt'

ft_model = fasttext.train_unsupervised(input=train_data, pretrainedVectors=path, dim=300)

# %%
# Saving the model
# ft_model.save_model("ft_model.bin")

# Loading the model
# ft_model = fasttext.load_model("ft_model.bin")

# %% [markdown]
# ### Labels

# %%
# Creating sentences for each document with the strongest tfidf words

tfidf_words_abstract = []

for text in tqdm(pdfs):
    tfidf_words_abstract.append(" ".join(find_top_n(text,vec_abs,10)))
    
tfidf_words_title = []

for text in tqdm(titles):
    tfidf_words_title.append(" ".join(find_top_n(text,vec_title,5)))
# Out:
# HBox(children=(IntProgress(value=0, max=99), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=99), HTML(value='')))

# %%
production_1 = ft_model.get_sentence_vector('selective laser melting')
production_2 = ft_model.get_sentence_vector('direct metal laser sintering')

production_3 = ft_model.get_sentence_vector('fused deposition modeling')
production_4 = ft_model.get_sentence_vector('fused filament fabrication')
production_5 = ft_model.get_sentence_vector('extrusion based additive manufacturing')

metal = ft_model.get_sentence_vector('metal')
ceramic = ft_model.get_sentence_vector('ceramic')
polymer = ft_model.get_sentence_vector('polymer')

# feature_1 = get_embedding('fracture toughness')
# feature_2 = get_embedding('tensile strength')
# feature_3 = get_embedding('yield strength')
# feature_4 = get_embedding('elastic modulus')
# feature_5 = get_embedding('strain fracture break')
# feature_6 = get_embedding('weibull modulus')

# %%
def pro_labeling(doc):
    
    production = []
    production_cos_score = []
    
    for text in tqdm(doc):
        
        text = ft_model.get_sentence_vector(text)
        
        lbl= []

        lbl.append(1-cosine(text,production_1))
        lbl.append(1-cosine(text,production_2))
        lbl.append(1-cosine(text,production_3))
        lbl.append(1-cosine(text,production_4))
        lbl.append(1-cosine(text,production_5))

        if lbl.index(max(lbl))==0 or lbl.index(max(lbl))==1:
            production.append('SLM or DMLS')
            production_cos_score.append(max(lbl))
        else:
            production.append('FDM or FFF or EAM')
            production_cos_score.append(max(lbl))
    
    return production , production_cos_score

# %%
def mat_labeling(doc):

    material = []  
    material_cos_score = []

    for text in tqdm(doc):
        
        text = ft_model.get_sentence_vector(text)
        
        lbl= []

        lbl.append(1-cosine(text,metal))
        lbl.append(1-cosine(text,ceramic))
        lbl.append(1-cosine(text,polymer))

        if lbl.index(max(lbl))==0:
            material.append('Metal')
            material_cos_score.append(max(lbl))
        elif lbl.index(max(lbl))==1:
            material.append('Ceramic')
            material_cos_score.append(max(lbl))
        else:
            material.append('Polymer')
            material_cos_score.append(max(lbl))
    
    return material , material_cos_score

# %%
def create_df_abs():
    
    d = {'Titles':title_list,
         'Abstracts':pdf_list,
         'Abs_Production':abs_production,
         'Abs_Production_score':abs_production_cos_score,
         'Abs_Material':abs_material,
         'Abs_Material_score':abs_material_cos_score
        }
    
    df = pd.DataFrame(d)
    #df["Production/Material"] = df["Abs_Production"] + " / " + df["Abs_Material"]
    
    return df

# %%
def create_df_title():
    
    d = {'Titles':title_list,
         'Abstracts':pdf_list,
         'Title_Production':title_production,
         'Title_Production_score':title_production_cos_score,
         'Title_Material':title_material,
         'Title_Material_score':title_material_cos_score
        }
    
    df = pd.DataFrame(d)
    #df["Production/Material"] = df["Title_Production"] + " / " + df["Title_Material"]
    
    return df

# %% [markdown]
# ### Labeling with abstracts and Titles

# %%
abs_production , abs_production_cos_score = pro_labeling(tfidf_words_abstract)
abs_material , abs_material_cos_score = mat_labeling(tfidf_words_abstract)
df_abs = create_df_abs()

title_production , title_production_cos_score = pro_labeling(tfidf_words_abstract)
title_material , title_material_cos_score = mat_labeling(tfidf_words_abstract)
df_title = create_df_title()
# Out:
# HBox(children=(IntProgress(value=0, max=99), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=99), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=99), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=99), HTML(value='')))

# %%
df_abs["Abs_Material"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Abs_Material'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-11b66efc0821> in <module>
# ----> 1 df_abs["Abs_Material"].value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Abs_Material'

# %%
df_title["Title_Material"].value_counts()
# Out:
# Polymer    42
# Ceramic    40
# Metal      17
# Name: Title_Material, dtype: int64

# %%
df_1 = create_df_abs()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-cf23fe15e061> in <module>
# ----> 1 df_1 = create_df_title()
#
# NameError: name 'create_df_title' is not defined

# %%
df_title.head(20)
# Out:
#                                                Titles  \
# 0           3D gel-printing of zirconia ceramic parts
# 1   3D Printed Glass Surface Finish and Bulk Prope...
# 2                    3D printing of ceramics A review
# 3   3D Printing of Continuous-Fiber Composites by ...
# 4                    3D Printing of Transparent Glass
# 5                  A Review of Additive Manufacturing
# 6   Additive manufacturing and its societal impact...
# 7   Additive manufacturing and mechanical characte...
# 8   Additive manufacturing of carbonfiber-reinforc...
# 9   Additive Manufacturing of Ceramic Based Materials
# 10  Additive manufacturing of ceramics issues, pot...
# 11  Additive Manufacturing of Dense Ceramic Parts ...
# 12                    Additive Manufacturing of Glass
# 13  Additive Manufacturing of Optically Transparen...
# 14  An experimental demonstration of effective Cur...
# 15  Anisotropic material properties of fused depos...
# 16  Anisotropic Mechanical Behavior of AlSi10Mg Pa...
# 17  Anisotropic mechanical properties of ABS parts...
# 18  Assessing the Structural Integrity of Additive...
# 19  Binding Mechanisms in Selective Laser Sinterin...
#
#                                             Abstracts   Title_Production  \
# 0   3D gel-printing (3DGP) is a new printing metho...  FDM or FFF or EAM
# 1   It is impossible to print glass directly from ...  FDM or FFF or EAM
# 2   Along with extensive research on the three-dim...  FDM or FFF or EAM
# 3   We have developed a method for the three-dimen...  FDM or FFF or EAM
# 4   Traditional assembly line manufacturing is spe...  FDM or FFF or EAM
# 5   Additive manufacturing processes take the info...  FDM or FFF or EAM
# 6   Thirty years into its development, additive ma...  FDM or FFF or EAM
# 7   Mechanical properties of additively manufactur...  FDM or FFF or EAM
# 8   Carbon fiber-reinforced plastic composites hav...  FDM or FFF or EAM
# 9   This paper offers a review of present achievem...  FDM or FFF or EAM
# 10  Additive manufacturing (AM) is a technology wh...  FDM or FFF or EAM
# 11  Additive manufacturing of near-net-shaped dens...  FDM or FFF or EAM
# 12  Selective laser melting (SLM) is a technique f...  FDM or FFF or EAM
# 13  We present a fully functional material extrusi...  FDM or FFF or EAM
# 14  Fused   Filament   Fabrication   (FFF)   is   ...  FDM or FFF or EAM
# 15  Rapid Prototyping (RP) technologies provide th...  FDM or FFF or EAM
# 16  AlSi 10Mg cylinders produced by laser powder-b...  FDM or FFF or EAM
# 17  Layered manufacturing (LM) methods have tradit...  FDM or FFF or EAM
# 18  This paper presents a study of structural inte...        SLM or DMLS
# 19  Layer Manufacturing (LM) technologies like Sel...        SLM or DMLS
#
#     Title_Production_score Title_Material  Title_Material_score
# 0                 0.861230        Ceramic              0.747950
# 1                 0.835402        Polymer              0.692100
# 2                 0.876732        Ceramic              0.778091
# 3                 0.849378        Polymer              0.750116
# 4                 0.843707        Polymer              0.687378
# 5                 0.921565        Ceramic              0.689773
# 6                 0.895693        Polymer              0.691979
# 7                 0.895395        Ceramic              0.719301
# 8                 0.925232        Polymer              0.699238
# 9                 0.888089        Ceramic              0.754961
# 10                0.891240        Ceramic              0.774748
# 11                0.797819        Polymer              0.688118
# 12                0.869322        Ceramic              0.692661
# 13                0.834542        Ceramic              0.685321
# 14                0.904479        Polymer              0.686434
# 15                0.836145        Polymer              0.712291
# 16                0.821470        Polymer              0.679538
# 17                0.879963        Ceramic              0.677263
# 18                0.850593          Metal              0.669727
# 19                0.861631        Polymer              0.717323

# %%
df_1.head(20)
# Out:
#                                                Titles  \
# 0           3D gel-printing of zirconia ceramic parts
# 1   3D Printed Glass Surface Finish and Bulk Prope...
# 2                    3D printing of ceramics A review
# 3   3D Printing of Continuous-Fiber Composites by ...
# 4                    3D Printing of Transparent Glass
# 5                  A Review of Additive Manufacturing
# 6   Additive manufacturing and its societal impact...
# 7   Additive manufacturing and mechanical characte...
# 8   Additive manufacturing of carbonfiber-reinforc...
# 9   Additive Manufacturing of Ceramic Based Materials
# 10  Additive manufacturing of ceramics issues, pot...
# 11  Additive Manufacturing of Dense Ceramic Parts ...
# 12                    Additive Manufacturing of Glass
# 13  Additive Manufacturing of Optically Transparen...
# 14  An experimental demonstration of effective Cur...
# 15  Anisotropic material properties of fused depos...
# 16  Anisotropic Mechanical Behavior of AlSi10Mg Pa...
# 17  Anisotropic mechanical properties of ABS parts...
# 18  Assessing the Structural Integrity of Additive...
# 19  Binding Mechanisms in Selective Laser Sinterin...
#
#                                             Abstracts Material_title  \
# 0   3D gel-printing (3DGP) is a new printing metho...        Ceramic
# 1   It is impossible to print glass directly from ...        Ceramic
# 2   Along with extensive research on the three-dim...        Ceramic
# 3   We have developed a method for the three-dimen...        Polymer
# 4   Traditional assembly line manufacturing is spe...        Polymer
# 5   Additive manufacturing processes take the info...        Ceramic
# 6   Thirty years into its development, additive ma...        Polymer
# 7   Mechanical properties of additively manufactur...        Ceramic
# 8   Carbon fiber-reinforced plastic composites hav...        Polymer
# 9   This paper offers a review of present achievem...        Ceramic
# 10  Additive manufacturing (AM) is a technology wh...        Ceramic
# 11  Additive manufacturing of near-net-shaped dens...        Polymer
# 12  Selective laser melting (SLM) is a technique f...        Ceramic
# 13  We present a fully functional material extrusi...        Ceramic
# 14  Fused   Filament   Fabrication   (FFF)   is   ...        Ceramic
# 15  Rapid Prototyping (RP) technologies provide th...        Polymer
# 16  AlSi 10Mg cylinders produced by laser powder-b...        Polymer
# 17  Layered manufacturing (LM) methods have tradit...        Ceramic
# 18  This paper presents a study of structural inte...        Polymer
# 19  Layer Manufacturing (LM) technologies like Sel...        Polymer
#
#     Material_title_score
# 0               0.748928
# 1               0.686253
# 2               0.778083
# 3               0.738717
# 4               0.698467
# 5               0.692488
# 6               0.679706
# 7               0.730757
# 8               0.698454
# 9               0.759091
# 10              0.774291
# 11              0.680183
# 12              0.701168
# 13              0.696323
# 14              0.689870
# 15              0.711883
# 16              0.670623
# 17              0.680370
# 18              0.667806
# 19              0.712764

# %% [markdown]
# Title

# %%
material , material_cos_score = material_labeling(fast_tfidf_2)
# Out:
# HBox(children=(IntProgress(value=0, max=99), HTML(value='')))

# %%
df_2 = create_df_title()
df_2["Material_title"].value_counts()
# Out:
# Ceramic    38
# Polymer    36
# Metal      25
# Name: Material_title, dtype: int64

# %%
df_2.head(20)
# Out:
#                                                Titles  \
# 0           3D gel-printing of zirconia ceramic parts
# 1   3D Printed Glass Surface Finish and Bulk Prope...
# 2                    3D printing of ceramics A review
# 3   3D Printing of Continuous-Fiber Composites by ...
# 4                    3D Printing of Transparent Glass
# 5                  A Review of Additive Manufacturing
# 6   Additive manufacturing and its societal impact...
# 7   Additive manufacturing and mechanical characte...
# 8   Additive manufacturing of carbonfiber-reinforc...
# 9   Additive Manufacturing of Ceramic Based Materials
# 10  Additive manufacturing of ceramics issues, pot...
# 11  Additive Manufacturing of Dense Ceramic Parts ...
# 12                    Additive Manufacturing of Glass
# 13  Additive Manufacturing of Optically Transparen...
# 14  An experimental demonstration of effective Cur...
# 15  Anisotropic material properties of fused depos...
# 16  Anisotropic Mechanical Behavior of AlSi10Mg Pa...
# 17  Anisotropic mechanical properties of ABS parts...
# 18  Assessing the Structural Integrity of Additive...
# 19  Binding Mechanisms in Selective Laser Sinterin...
#
#                                             Abstracts Material_title  \
# 0   3D gel-printing (3DGP) is a new printing metho...        Ceramic
# 1   It is impossible to print glass directly from ...        Polymer
# 2   Along with extensive research on the three-dim...        Ceramic
# 3   We have developed a method for the three-dimen...          Metal
# 4   Traditional assembly line manufacturing is spe...        Polymer
# 5   Additive manufacturing processes take the info...        Ceramic
# 6   Thirty years into its development, additive ma...        Ceramic
# 7   Mechanical properties of additively manufactur...        Polymer
# 8   Carbon fiber-reinforced plastic composites hav...        Polymer
# 9   This paper offers a review of present achievem...        Ceramic
# 10  Additive manufacturing (AM) is a technology wh...        Ceramic
# 11  Additive manufacturing of near-net-shaped dens...        Ceramic
# 12  Selective laser melting (SLM) is a technique f...        Polymer
# 13  We present a fully functional material extrusi...        Polymer
# 14  Fused   Filament   Fabrication   (FFF)   is   ...        Polymer
# 15  Rapid Prototyping (RP) technologies provide th...        Polymer
# 16  AlSi 10Mg cylinders produced by laser powder-b...        Ceramic
# 17  Layered manufacturing (LM) methods have tradit...        Polymer
# 18  This paper presents a study of structural inte...          Metal
# 19  Layer Manufacturing (LM) technologies like Sel...          Metal
#
#     Material_title_score
# 0               0.811637
# 1               0.669838
# 2               0.774375
# 3               0.668096
# 4               0.684957
# 5               0.663333
# 6               0.674304
# 7               0.677085
# 8               0.687831
# 9               0.788638
# 10              0.788562
# 11              0.781174
# 12              0.689238
# 13              0.681612
# 14              0.679512
# 15              0.677741
# 16              0.651280
# 17              0.713658
# 18              0.776613
# 19              0.682247

# %%
df_2['Material_abstract'] = df_1['Material_title']
df_2['Material_abstract_score'] = df_1['Material_title_score']

# %%
df_2.head()
# Out:
#                                               Titles  \
# 0          3D gel-printing of zirconia ceramic parts
# 1  3D Printed Glass Surface Finish and Bulk Prope...
# 2                   3D printing of ceramics A review
# 3  3D Printing of Continuous-Fiber Composites by ...
# 4                   3D Printing of Transparent Glass
#
#                                            Abstracts Material_title  \
# 0  3D gel-printing (3DGP) is a new printing metho...        Ceramic
# 1  It is impossible to print glass directly from ...        Polymer
# 2  Along with extensive research on the three-dim...        Ceramic
# 3  We have developed a method for the three-dimen...          Metal
# 4  Traditional assembly line manufacturing is spe...        Polymer
#
#    Material_title_score Material_abstract  Material_abstract_score
# 0              0.811637           Ceramic                 0.748928
# 1              0.669838           Ceramic                 0.686253
# 2              0.774375           Ceramic                 0.778083
# 3              0.668096           Polymer                 0.738717
# 4              0.684957           Polymer                 0.698467

# %%
df_2 = df_2.drop('que',axis=1)

# %%
def que(x):
    if x['Material_title'] == x['Material_abstract']:
        return True
    else:
        return False
    
df_2['que'] = df_2.apply(que, axis=1)

# %%
# df_2['que'].apply(lambda x:"x['que']" ,if x =="Ceramic",axis=1)

# %%
# sum(df_2['que'])

# %%
df_2.head()
# Out:
#                                               Titles  \
# 0          3D gel-printing of zirconia ceramic parts
# 1  3D Printed Glass Surface Finish and Bulk Prope...
# 2                   3D printing of ceramics A review
# 3  3D Printing of Continuous-Fiber Composites by ...
# 4                   3D Printing of Transparent Glass
#
#                                            Abstracts Material_title  \
# 0  3D gel-printing (3DGP) is a new printing metho...        Ceramic
# 1  It is impossible to print glass directly from ...        Polymer
# 2  Along with extensive research on the three-dim...        Ceramic
# 3  We have developed a method for the three-dimen...          Metal
# 4  Traditional assembly line manufacturing is spe...        Polymer
#
#    Material_title_score Material_abstract  Material_abstract_score    que
# 0              0.811637           Ceramic                 0.748928   True
# 1              0.669838           Ceramic                 0.686253  False
# 2              0.774375           Ceramic                 0.778083   True
# 3              0.668096           Polymer                 0.738717  False
# 4              0.684957           Polymer                 0.698467   True

# %%
df_2 = df_2[['Titles','Abstracts','Material_abstract','Material_abstract_score','Material_title','Material_title_score','que']]

# %%
df_2.head(35)
# Out:
#                                                Titles  \
# 0           3D gel-printing of zirconia ceramic parts
# 1   3D Printed Glass Surface Finish and Bulk Prope...
# 2                    3D printing of ceramics A review
# 3   3D Printing of Continuous-Fiber Composites by ...
# 4                    3D Printing of Transparent Glass
# 5                  A Review of Additive Manufacturing
# 6   Additive manufacturing and its societal impact...
# 7   Additive manufacturing and mechanical characte...
# 8   Additive manufacturing of carbonfiber-reinforc...
# 9   Additive Manufacturing of Ceramic Based Materials
# 10  Additive manufacturing of ceramics issues, pot...
# 11  Additive Manufacturing of Dense Ceramic Parts ...
# 12                    Additive Manufacturing of Glass
# 13  Additive Manufacturing of Optically Transparen...
# 14  An experimental demonstration of effective Cur...
# 15  Anisotropic material properties of fused depos...
# 16  Anisotropic Mechanical Behavior of AlSi10Mg Pa...
# 17  Anisotropic mechanical properties of ABS parts...
# 18  Assessing the Structural Integrity of Additive...
# 19  Binding Mechanisms in Selective Laser Sinterin...
# 20  Carbon, glass and kevlar fibre reinforce polym...
# 21  Cellular Ti–6Al–4V structures with interconnec...
# 22  Combined additive manufacturing approaches in ...
# 23  Comparison of Residual Stresses in Inconel 718...
# 24  Correlation between porosity and processing pa...
# 25  Defect Formation Mechanisms in Selective Laser...
# 26  Defect Morphology of Ti-6Al-4V Parts Fabricate...
# 27  Deformation and failure behaviour of Ti-6Al-4V...
# 28  DESIGN AND TOPOLOGY OPTIMIZATION FOR ADDITIVEL...
# 29  Direct metal fabrication of titanium implants ...
# 30  Direct Metal Laser Sintering, an additive manu...
# 31  Ductility of a Ti-6Al-4V alloy produced by sel...
# 32  Duplex stainless steel fabricated by selective...
# 33  Effect of annealing procedure on the bonding o...
# 34  EFFECT OF DEFECTS ON FATIGUE TESTS OF AS-BUILT...
#
#                                             Abstracts Material_abstract  \
# 0   3D gel-printing (3DGP) is a new printing metho...           Ceramic
# 1   It is impossible to print glass directly from ...           Ceramic
# 2   Along with extensive research on the three-dim...           Ceramic
# 3   We have developed a method for the three-dimen...           Polymer
# 4   Traditional assembly line manufacturing is spe...           Polymer
# 5   Additive manufacturing processes take the info...           Ceramic
# 6   Thirty years into its development, additive ma...           Polymer
# 7   Mechanical properties of additively manufactur...           Ceramic
# 8   Carbon fiber-reinforced plastic composites hav...           Polymer
# 9   This paper offers a review of present achievem...           Ceramic
# 10  Additive manufacturing (AM) is a technology wh...           Ceramic
# 11  Additive manufacturing of near-net-shaped dens...           Polymer
# 12  Selective laser melting (SLM) is a technique f...           Ceramic
# 13  We present a fully functional material extrusi...           Ceramic
# 14  Fused   Filament   Fabrication   (FFF)   is   ...           Ceramic
# 15  Rapid Prototyping (RP) technologies provide th...           Polymer
# 16  AlSi 10Mg cylinders produced by laser powder-b...           Polymer
# 17  Layered manufacturing (LM) methods have tradit...           Ceramic
# 18  This paper presents a study of structural inte...           Polymer
# 19  Layer Manufacturing (LM) technologies like Sel...           Polymer
# 20  This   study   evaluates   the   performance  ...           Polymer
# 21  Selective electron beam melting (SEBM) was suc...           Ceramic
# 22  Advances introduced by additive manufacturing ...           Ceramic
# 23  Residual stress proﬁles were mapped using neut...             Metal
# 24  This study presents the correlation between pr...           Ceramic
# 25  Defect formation is a common problem in select...           Ceramic
# 26  In order to investigate the morphology of defe...           Ceramic
# 27  Selective laser melting (SLM) enables the manu...           Ceramic
# 28  Formula Student is a worldwide project for eng...           Ceramic
# 29  The design of custom or tailored implant compo...           Ceramic
# 30  Direct metal laser sintering (DMLS) is an addi...             Metal
# 31  Purpose – The aim of the paper is the study of...             Metal
# 32  In the scope of the present study, microstruct...             Metal
# 33  An annealing procedure is a heat treatment pro...           Ceramic
# 34  Defects can be found in parts made using Selec...           Ceramic
#
#     Material_abstract_score Material_title  Material_title_score    que
# 0                  0.748928        Ceramic              0.811637   True
# 1                  0.686253        Polymer              0.669838  False
# 2                  0.778083        Ceramic              0.774375   True
# 3                  0.738717          Metal              0.668096  False
# 4                  0.698467        Polymer              0.684957   True
# 5                  0.692488        Ceramic              0.663333   True
# 6                  0.679706        Ceramic              0.674304  False
# 7                  0.730757        Polymer              0.677085  False
# 8                  0.698454        Polymer              0.687831   True
# 9                  0.759091        Ceramic              0.788638   True
# 10                 0.774291        Ceramic              0.788562   True
# 11                 0.680183        Ceramic              0.781174  False
# 12                 0.701168        Polymer              0.689238  False
# 13                 0.696323        Polymer              0.681612  False
# 14                 0.689870        Polymer              0.679512  False
# 15                 0.711883        Polymer              0.677741   True
# 16                 0.670623        Ceramic              0.651280  False
# 17                 0.680370        Polymer              0.713658  False
# 18                 0.667806          Metal              0.776613  False
# 19                 0.712764          Metal              0.682247  False
# 20                 0.704295        Polymer              0.813953   True
# 21                 0.667891          Metal              0.647453  False
# 22                 0.682228        Ceramic              0.664194   True
# 23                 0.733339        Polymer              0.675181  False
# 24                 0.668306        Ceramic              0.672881   True
# 25                 0.660815        Ceramic              0.664305   True
# 26                 0.666614          Metal              0.643387  False
# 27                 0.644471          Metal              0.627428  False
# 28                 0.691021        Ceramic              0.677273   True
# 29                 0.695884        Ceramic              0.633508   True
# 30                 0.746853          Metal              0.685671   True
# 31                 0.692691          Metal              0.655248   True
# 32                 0.654489          Metal              0.658627   True
# 33                 0.789286        Ceramic              0.796563   True
# 34                 0.639863          Metal              0.618317  False

# %%
df_2 = df_2.drop(['que'],axis=1)

# %%
df_2
# Out:
#                                                Titles  \
# 0           3D gel-printing of zirconia ceramic parts
# 1   3D Printed Glass Surface Finish and Bulk Prope...
# 2                    3D printing of ceramics A review
# 3   3D Printing of Continuous-Fiber Composites by ...
# 4                    3D Printing of Transparent Glass
# ..                                                ...
# 94  The guide to glass 3D printing developments, m...
# 95  The impact of process parameters on mechanical...
# 96  Thermo-mechanical Characterization of MetalPol...
# 97  Three-dimensional printed strontium-containing...
# 98    Three-dimensional printing of a bioactive glass
#
#                                             Abstracts Material_title  \
# 0   3D gel-printing (3DGP) is a new printing metho...        Ceramic
# 1   It is impossible to print glass directly from ...        Polymer
# 2   Along with extensive research on the three-dim...        Ceramic
# 3   We have developed a method for the three-dimen...          Metal
# 4   Traditional assembly line manufacturing is spe...        Polymer
# ..                                                ...            ...
# 94  Purpose – This purpose of this paper is to pro...        Ceramic
# 95  Purpose – This study aims to quantify the ulti...        Polymer
# 96  New metal/polymer composite filaments for fuse...        Ceramic
# 97  The development of a new generation of biomate...        Ceramic
# 98  We report on three-dimensional printing and su...        Polymer
#
#     Material_title_score
# 0               0.811637
# 1               0.669838
# 2               0.774375
# 3               0.668096
# 4               0.684957
# ..                   ...
# 94              0.694928
# 95              0.700567
# 96              0.724027
# 97              0.664514
# 98              0.681154
#
# [99 rows x 4 columns]

# %%
def production_labeling(doc):
    
    production = []
    production_cos_score = []
    
    for text in tqdm(doc):
        
        text = ft_model.get_sentence_vector(text)
        
        lbl= []

        lbl.append(1-cosine(text,label_1))
        lbl.append(1-cosine(text,label_2))
        lbl.append(1-cosine(text,label_3))
        lbl.append(1-cosine(text,label_4))
        lbl.append(1-cosine(text,label_5))

        if lbl.index(max(lbl))==0 or lbl.index(max(lbl))==1:
            production.append('SLM or DMLS')
            production_cos_score.append(max(lbl))
        else:
            production.append('FDM or FFF or EAM')
            production_cos_score.append(max(lbl))
    
    # Finding cosine scores
    #production_cos_score = list(map(float,production_cos_score))
    #production_cos_score = list(map(lambda x: round(x,2), production_cos_score)) 
    
    return production , production_cos_score

# %%
production , production_cos_score = production_labeling(fast_tfidf_2)
# Out:
# HBox(children=(IntProgress(value=0, max=99), HTML(value='')))

# %%
df_2['Production_title'] = production

# %%
df_2['Production_title_score'] = production_cos_score

# %%
df_2.head(35)
# Out:
#                                                Titles  \
# 0           3D gel-printing of zirconia ceramic parts
# 1   3D Printed Glass Surface Finish and Bulk Prope...
# 2                    3D printing of ceramics A review
# 3   3D Printing of Continuous-Fiber Composites by ...
# 4                    3D Printing of Transparent Glass
# 5                  A Review of Additive Manufacturing
# 6   Additive manufacturing and its societal impact...
# 7   Additive manufacturing and mechanical characte...
# 8   Additive manufacturing of carbonfiber-reinforc...
# 9   Additive Manufacturing of Ceramic Based Materials
# 10  Additive manufacturing of ceramics issues, pot...
# 11  Additive Manufacturing of Dense Ceramic Parts ...
# 12                    Additive Manufacturing of Glass
# 13  Additive Manufacturing of Optically Transparen...
# 14  An experimental demonstration of effective Cur...
# 15  Anisotropic material properties of fused depos...
# 16  Anisotropic Mechanical Behavior of AlSi10Mg Pa...
# 17  Anisotropic mechanical properties of ABS parts...
# 18  Assessing the Structural Integrity of Additive...
# 19  Binding Mechanisms in Selective Laser Sinterin...
# 20  Carbon, glass and kevlar fibre reinforce polym...
# 21  Cellular Ti–6Al–4V structures with interconnec...
# 22  Combined additive manufacturing approaches in ...
# 23  Comparison of Residual Stresses in Inconel 718...
# 24  Correlation between porosity and processing pa...
# 25  Defect Formation Mechanisms in Selective Laser...
# 26  Defect Morphology of Ti-6Al-4V Parts Fabricate...
# 27  Deformation and failure behaviour of Ti-6Al-4V...
# 28  DESIGN AND TOPOLOGY OPTIMIZATION FOR ADDITIVEL...
# 29  Direct metal fabrication of titanium implants ...
# 30  Direct Metal Laser Sintering, an additive manu...
# 31  Ductility of a Ti-6Al-4V alloy produced by sel...
# 32  Duplex stainless steel fabricated by selective...
# 33  Effect of annealing procedure on the bonding o...
# 34  EFFECT OF DEFECTS ON FATIGUE TESTS OF AS-BUILT...
#
#                                             Abstracts Material_title  \
# 0   3D gel-printing (3DGP) is a new printing metho...        Ceramic
# 1   It is impossible to print glass directly from ...        Polymer
# 2   Along with extensive research on the three-dim...        Ceramic
# 3   We have developed a method for the three-dimen...          Metal
# 4   Traditional assembly line manufacturing is spe...        Polymer
# 5   Additive manufacturing processes take the info...        Ceramic
# 6   Thirty years into its development, additive ma...        Ceramic
# 7   Mechanical properties of additively manufactur...        Polymer
# 8   Carbon fiber-reinforced plastic composites hav...        Polymer
# 9   This paper offers a review of present achievem...        Ceramic
# 10  Additive manufacturing (AM) is a technology wh...        Ceramic
# 11  Additive manufacturing of near-net-shaped dens...        Ceramic
# 12  Selective laser melting (SLM) is a technique f...        Polymer
# 13  We present a fully functional material extrusi...        Polymer
# 14  Fused   Filament   Fabrication   (FFF)   is   ...        Polymer
# 15  Rapid Prototyping (RP) technologies provide th...        Polymer
# 16  AlSi 10Mg cylinders produced by laser powder-b...        Ceramic
# 17  Layered manufacturing (LM) methods have tradit...        Polymer
# 18  This paper presents a study of structural inte...          Metal
# 19  Layer Manufacturing (LM) technologies like Sel...          Metal
# 20  This   study   evaluates   the   performance  ...        Polymer
# 21  Selective electron beam melting (SEBM) was suc...          Metal
# 22  Advances introduced by additive manufacturing ...        Ceramic
# 23  Residual stress proﬁles were mapped using neut...        Polymer
# 24  This study presents the correlation between pr...        Ceramic
# 25  Defect formation is a common problem in select...        Ceramic
# 26  In order to investigate the morphology of defe...          Metal
# 27  Selective laser melting (SLM) enables the manu...          Metal
# 28  Formula Student is a worldwide project for eng...        Ceramic
# 29  The design of custom or tailored implant compo...        Ceramic
# 30  Direct metal laser sintering (DMLS) is an addi...          Metal
# 31  Purpose – The aim of the paper is the study of...          Metal
# 32  In the scope of the present study, microstruct...          Metal
# 33  An annealing procedure is a heat treatment pro...        Ceramic
# 34  Defects can be found in parts made using Selec...          Metal
#
#     Material_title_score   Production_title  Production_title_score
# 0               0.811637  FDM or FFF or EAM                0.851035
# 1               0.669838  FDM or FFF or EAM                0.828517
# 2               0.774375  FDM or FFF or EAM                0.824353
# 3               0.668096  FDM or FFF or EAM                0.808019
# 4               0.684957  FDM or FFF or EAM                0.828058
# 5               0.663333  FDM or FFF or EAM                0.925872
# 6               0.674304  FDM or FFF or EAM                0.910155
# 7               0.677085  FDM or FFF or EAM                0.798030
# 8               0.687831  FDM or FFF or EAM                0.922813
# 9               0.788638  FDM or FFF or EAM                0.954266
# 10              0.788562  FDM or FFF or EAM                0.934466
# 11              0.781174        SLM or DMLS                0.855194
# 12              0.689238  FDM or FFF or EAM                0.923646
# 13              0.681612  FDM or FFF or EAM                0.941231
# 14              0.679512  FDM or FFF or EAM                0.888224
# 15              0.677741  FDM or FFF or EAM                0.935753
# 16              0.651280        SLM or DMLS                0.905759
# 17              0.713658  FDM or FFF or EAM                0.912409
# 18              0.776613        SLM or DMLS                0.859188
# 19              0.682247        SLM or DMLS                0.951140
# 20              0.813953  FDM or FFF or EAM                0.802858
# 21              0.647453        SLM or DMLS                0.816613
# 22              0.664194  FDM or FFF or EAM                0.874972
# 23              0.675181  FDM or FFF or EAM                0.864924
# 24              0.672881        SLM or DMLS                0.842106
# 25              0.664305  FDM or FFF or EAM                0.805380
# 26              0.643387        SLM or DMLS                0.848139
# 27              0.627428        SLM or DMLS                0.800587
# 28              0.677273  FDM or FFF or EAM                0.877196
# 29              0.633508        SLM or DMLS                0.846057
# 30              0.685671        SLM or DMLS                0.878538
# 31              0.655248        SLM or DMLS                0.852368
# 32              0.658627        SLM or DMLS                0.848173
# 33              0.796563        SLM or DMLS                0.825812
# 34              0.618317        SLM or DMLS                0.795305

# %%
df_2['Production_title'].value_counts()
# Out:
# FDM or FFF or EAM    69
# SLM or DMLS          30
# Name: Production_title, dtype: int64

# %%
df_2.to_excel("recent_results.xlsx")

# %%
def r(x):
    return round(x,2)

df_2["Material_title_score"] = df_2["Material_title_score"].apply(lambda x:round(x,2))
df_2["Production_title_score"] = df_2["Production_title_score"].apply(lambda x:round(x,2))

# %%
df_2.head()
# Out:
#                                               Titles  \
# 0          3D gel-printing of zirconia ceramic parts
# 1  3D Printed Glass Surface Finish and Bulk Prope...
# 2                   3D printing of ceramics A review
# 3  3D Printing of Continuous-Fiber Composites by ...
# 4                   3D Printing of Transparent Glass
#
#                                            Abstracts Material_title  \
# 0  3D gel-printing (3DGP) is a new printing metho...        Ceramic
# 1  It is impossible to print glass directly from ...        Polymer
# 2  Along with extensive research on the three-dim...        Ceramic
# 3  We have developed a method for the three-dimen...          Metal
# 4  Traditional assembly line manufacturing is spe...        Polymer
#
#    Material_title_score   Production_title  Production_title_score
# 0                  0.81  FDM or FFF or EAM                    0.85
# 1                  0.67  FDM or FFF or EAM                    0.83
# 2                  0.77  FDM or FFF or EAM                    0.82
# 3                  0.67  FDM or FFF or EAM                    0.81
# 4                  0.68  FDM or FFF or EAM                    0.83

# %%
df_2.to_excel("recent_results.xlsx")
